# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import module
from module import *
import importlib
importlib.reload(module)
import readpng as rpng

# %%
img=rpng.get_img("./car.png")

# %%
np.shape(img)
# Out:
# (366, 408, 3)

# %%
fig=plt.figure()

#timg=img[100:175,100:250]
#timg=img[100:175:2,100:250:2]
timg=img[::8,::8,:]
plt.imshow(timg)

# %%
Nx, Ny, Nc = np.shape(timg)
N_data = 300
rand_now = module.random_generator(N_data, Nx, Ny)
dR, gR=rand_now.make_data(timg[:,:,0],10) 
dG, gG=rand_now.make_data(timg[:,:,1],10) 
dB, gB=rand_now.make_data(timg[:,:,2],10) 
gR = np.array(gR)
gG = np.array(gG)
gB = np.array(gB)

# %%
np.shape(g)
# Out:
# (300, 46, 51)

# %%
I_init=np.ones((Nx,Ny))
yR = mfista_func(I_init, dR, gR, lambda_l1= 1e-6, lambda_tsv= 1e-3)
I_init=np.ones((Nx,Ny))
yG = mfista_func(I_init, dG, gG, lambda_l1= 1e-6, lambda_tsv= 1e-3)
I_init=np.ones((Nx,Ny))
yB = mfista_func(I_init, dB, gB, lambda_l1= 1e-6, lambda_tsv= 1e-3)
# Out:
# 25.164570331573486 49.11857604980469 1.2662010192871094 SEC in total
# 18.15026879310608 35.54816460609436 0.8908200263977051 SEC in total
# 19.69260835647583 40.01266169548035 0.9593994617462158 SEC in total

# %%
y=np.array([yR.T,yG.T,yB.T]).T
np.shape(y)
# Out:
# (46, 51, 3)

# %%
plt.imshow(y)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
np.shape(timg)
# Out:
# (46, 51, 3)
